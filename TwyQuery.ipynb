# %%
from twython import Twython, TwythonStreamer

# %%
from auth import *

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
from pprint import pprint

# %%
print(CONSUMER_KEY)
# Out:
# 5dOy7eBpSdEiYQMs4Ch5f8Rog

# %%
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# %%
for status in twitter.search(q='beer')['statuses']:
    time = status['created_at']
    tweet = status['text'].encode('utf-8')
    influence = status['favorite_count']
    pprint(status)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:02:00 +0000 2018',
#  'entities': {'hashtags': [{'indices': [99, 109], 'text': 'TheRapper'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 856939208383930368,
#                                  'id_str': '856939208383930368',
#                                  'indices': [3, 17],
#                                  'name': 'มะพร้าวนมสดปั่นแก้วนึงครับ',
#                                  'screen_name': 'lunalunelalin'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954424599166977,
#  'id_str': '990954424599166977',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'th',
#  'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 11021,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Mon Apr 23 14:02:47 +0000 2018',
#                       'entities': {'hashtags': [{'indices': [80, 90],
#                                                  'text': 'TheRapper'}],
#                                    'symbols': [],
#                                    'urls': [],
#                                    'user_mentions': []},
#                       'favorite_count': 2089,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 988417905871151105,
#                       'id_str': '988417905871151105',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'th',
#                       'metadata': {'iso_language_code': 'th',
#                                    'result_type': 'recent'},
#                       'place': None,
#                       'retweet_count': 11021,
#                       'retweeted': False,
#                       'source': '<a href="http://twitter.com/download/android" '
#                                 'rel="nofollow">Twitter for Android</a>',
#                       'text': 'อายุ13ผมก็แรป\n'
#                               '\n'
#                               '.\n'
#                               '.\n'
#                               '.\n'
#                               '.\n'
#                               '.\n'
#                               'แรปถาดผลไม้ ถาดละ20ครับ '
#                               'ช่วยซื้อหน่อยอยากกลับบ้านเร็วๆ #TheRapper',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Tue Apr 25 18:33:23 +0000 2017',
#                                'default_profile': True,
#                                'default_profile_image': False,
#                                'description': '',
#                                'entities': {'description': {'urls': []}},
#                                'favourites_count': 1015,
#                                'follow_request_sent': None,
#                                'followers_count': 32,
#                                'following': None,
#                                'friends_count': 49,
#                                'geo_enabled': True,
#                                'has_extended_profile': True,
#                                'id': 856939208383930368,
#                                'id_str': '856939208383930368',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'th',
#                                'listed_count': 0,
#                                'location': 'กรุงเทพมหานคร, ประเทศไทย',
#                                'name': 'มะพร้าวนมสดปั่นแก้วนึงครับ',
#                                'notifications': None,
#                                'profile_background_color': 'F5F8FA',
#                                'profile_background_image_url': None,
#                                'profile_background_image_url_https': None,
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/856939208383930368/1515680538',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/987655419496579072/1CgRjOef_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/987655419496579072/1CgRjOef_normal.jpg',
#                                'profile_link_color': '1DA1F2',
#                                'profile_sidebar_border_color': 'C0DEED',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'lunalunelalin',
#                                'statuses_count': 1347,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': None,
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @lunalunelalin: อายุ13ผมก็แรป\n'
#          '\n'
#          '.\n'
#          '.\n'
#          '.\n'
#          '.\n'
#          '.\n'
#          'แรปถาดผลไม้ ถาดละ20ครับ ช่วยซื้อหน่อยอยากกลับบ้านเร็วๆ #TheRapper',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Nov 18 08:02:56 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '#1997 #QingYu #WangQing #FengJainyu ♦️',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 1565,
#           'follow_request_sent': None,
#           'followers_count': 178,
#           'following': None,
#           'friends_count': 761,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 415381225,
#           'id_str': '415381225',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 4,
#           'location': 'Trang',
#           'name': 'beerforgot',
#           'notifications': None,
#           'profile_background_color': 'BADFCD',
#           'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/684980838807678976/uOBt37bK.jpg',
#           'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/684980838807678976/uOBt37bK.jpg',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/415381225/1460657463',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/820856428424359936/m3duM21r_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820856428424359936/m3duM21r_normal.jpg',
#           'profile_link_color': 'E81C4F',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': 'F5F0F5',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'Beer_Kanyarat',
#           'statuses_count': 56895,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:59 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 378027118,
#                                  'id_str': '378027118',
#                                  'indices': [0, 10],
#                                  'name': '水萌📷*撮影依頼は固定ツイ必読で🙏',
#                                  'screen_name': 'minamo_00'},
#                                 {'id': 586516807,
#                                  'id_str': '586516807',
#                                  'indices': [11, 20],
#                                  'name': 'まめ太◎5/4東1ス52a',
#                                  'screen_name': 'mmt_beer'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954421134671873,
#  'id_str': '990954421134671873',
#  'in_reply_to_screen_name': 'minamo_00',
#  'in_reply_to_status_id': 990953601018155010,
#  'in_reply_to_status_id_str': '990953601018155010',
#  'in_reply_to_user_id': 378027118,
#  'in_reply_to_user_id_str': '378027118',
#  'is_quote_status': False,
#  'lang': 'ja',
#  'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': '@minamo_00 @mmt_beer 生きのいいブレが釣れた（びちびち',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Jan 29 06:23:45 +0000 2010',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '極たまにmmderいじりしつつ絵や漫画描いてます。主にヘタリア：西ロマ中心\n'
#                          'ﾋﾟｸｼﾌﾞ・ﾋﾟｱﾌﾟﾛ・ﾆｺ生・ｴﾌﾞﾘｽﾀ登録済\n'
#                          '現在熱いもの⇒ﾍﾀ/西ﾛﾏ悪友 とうらぶ/むっちゃん ﾎﾞｶﾛ/ﾚﾝ廃 創作ｵﾘｼﾞ/常にＢＬ脳（） '
#                          '＊絵や写真の無断転載はご遠慮ください。',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'pipa.jp/tegaki/376080/',
#                                          'expanded_url': 'http://pipa.jp/tegaki/376080/',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/OgnSjyYosi'}]}},
#           'favourites_count': 527,
#           'follow_request_sent': None,
#           'followers_count': 1204,
#           'following': None,
#           'friends_count': 519,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 109489639,
#           'id_str': '109489639',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'ja',
#           'listed_count': 50,
#           'location': 'トマト領\u3000三',
#           'name': 'kiriya@scc東2/ﾁ50a',
#           'notifications': None,
#           'profile_background_color': 'C2C2C2',
#           'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/835286002/561565758c6882cf5faec59760a65adf.png',
#           'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/835286002/561565758c6882cf5faec59760a65adf.png',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/109489639/1516853122',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/886478657518096384/RzBSWiWA_normal.png',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/886478657518096384/RzBSWiWA_normal.png',
#           'profile_link_color': '981CEB',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'yumemiyan',
#           'statuses_count': 38516,
#           'time_zone': 'Tokyo',
#           'translator_type': 'none',
#           'url': 'https://t.co/OgnSjyYosi',
#           'utc_offset': 32400,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:57 +0000 2018',
#  'entities': {'hashtags': [{'indices': [24, 29], 'text': 'beer'},
#                            {'indices': [30, 36], 'text': 'ビールクズ'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954412192362496,
#  'id_str': '990954412192362496',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'ja',
#  'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://makebot.sh" rel="nofollow">ビール飲みたいbot</a>',
#  'text': 'ビールを知っていることと実際に飲むことは違う。 #beer #ビールクズ',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Jul 25 23:28:15 +0000 2013',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': '吾は英雄だ。ビールクズとも言う。',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 0,
#           'follow_request_sent': None,
#           'followers_count': 380,
#           'following': None,
#           'friends_count': 352,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 1621528022,
#           'id_str': '1621528022',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'ja',
#           'listed_count': 23,
#           'location': 'ビールがあるところ',
#           'name': 'ビール飲みたいbot',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1621528022/1374900080',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000190518632/f30eb3647fcefe90ac4c6a5e8199f24d_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000190518632/f30eb3647fcefe90ac4c6a5e8199f24d_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'beer_nomou_bot',
#           'statuses_count': 45527,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:57 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                         'expanded_url': 'https://twitter.com/i/web/status/990954411970179078',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/pkdOGiSXTS'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954411970179078,
#  'id_str': '990954411970179078',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': "Stupid joke of the day: I know there's a beer called Perlenbacher, "
#          'but I have an idea for a beer called Offenbacher… '
#          'https://t.co/pkdOGiSXTS',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Oct 08 20:41:45 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': '',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 84056,
#           'follow_request_sent': None,
#           'followers_count': 378,
#           'following': None,
#           'friends_count': 521,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 2816781159,
#           'id_str': '2816781159',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en-gb',
#           'listed_count': 12,
#           'location': 'Sweden',
#           'name': 'Kris Viking',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/837317715098492928/Af7E15bW_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837317715098492928/Af7E15bW_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MrKrisViking',
#           'statuses_count': 19083,
#           'time_zone': 'Stockholm',
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': 7200,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:57 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 347086840,
#                                  'id_str': '347086840',
#                                  'indices': [0, 15],
#                                  'name': 'Hobgoblin',
#                                  'screen_name': 'Hobgoblin_beer'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954411378659328,
#  'id_str': '990954411378659328',
#  'in_reply_to_screen_name': 'Hobgoblin_beer',
#  'in_reply_to_status_id': 989822639886733312,
#  'in_reply_to_status_id_str': '989822639886733312',
#  'in_reply_to_user_id': 347086840,
#  'in_reply_to_user_id_str': '347086840',
#  'is_quote_status': False,
#  'lang': 'und',
#  'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://twitaculous.com/" rel="nofollow">Twitaculous - '
#            'Win Stuff!</a>',
#  'text': '@Hobgoblin_beer .. 🔋📬⌚️',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Aug 15 13:33:12 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '❤❤❤❤ Without my children my house would be clean and '
#                          'my wallet would be full but my HEART would be empty '
#                          '❤❤❤❤',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 37958,
#           'follow_request_sent': None,
#           'followers_count': 4909,
#           'following': None,
#           'friends_count': 5407,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 355509893,
#           'id_str': '355509893',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1513,
#           'location': 'London, England',
#           'name': 'EVA',
#           'notifications': None,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/355509893/1518393411',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/986002892996964354/l7ybgUZ2_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/986002892996964354/l7ybgUZ2_normal.jpg',
#           'profile_link_color': 'E81C4F',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'wiseat47',
#           'statuses_count': 712803,
#           'time_zone': 'London',
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': 3600,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:55 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 21411216,
#                                  'id_str': '21411216',
#                                  'indices': [3, 19],
#                                  'name': 'Heather Hogan',
#                                  'screen_name': 'theheatherhogan'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954403787132929,
#  'id_str': '990954403787132929',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 33,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Apr 29 23:02:51 +0000 2018',
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                                              'expanded_url': 'https://twitter.com/i/web/status/990728145740488706',
#                                              'indices': [117, 140],
#                                              'url': 'https://t.co/wawrzqHyOI'}],
#                                    'user_mentions': []},
#                       'favorite_count': 606,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 990728145740488706,
#                       'id_str': '990728145740488706',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'metadata': {'iso_language_code': 'en',
#                                    'result_type': 'recent'},
#                       'place': None,
#                       'retweet_count': 33,
#                       'retweeted': False,
#                       'source': '<a href="http://twitter.com/download/iphone" '
#                                 'rel="nofollow">Twitter for iPhone</a>',
#                       'text': 'Guy to bartender: “I’m working with some '
#                               'celebrities right now. People with three '
#                               'thousand followers will come to y… '
#                               'https://t.co/wawrzqHyOI',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Fri Feb 20 16:41:34 +0000 2009',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'senior editor: @autostraddle | '
#                                               'member: @officialtca, '
#                                               '@DorianAwards | heather at '
#                                               'autostraddle dot com | opinions '
#                                               'my own',
#                                'entities': {'description': {'urls': []},
#                                             'url': {'urls': [{'display_url': 'autostraddle.com/author/heather…',
#                                                               'expanded_url': 'http://www.autostraddle.com/author/heatherannehogan/',
#                                                               'indices': [0,
#                                                                           23],
#                                                               'url': 'https://t.co/kZv3R2lryS'}]}},
#                                'favourites_count': 36371,
#                                'follow_request_sent': None,
#                                'followers_count': 22283,
#                                'following': None,
#                                'friends_count': 594,
#                                'geo_enabled': False,
#                                'has_extended_profile': True,
#                                'id': 21411216,
#                                'id_str': '21411216',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 335,
#                                'location': 'New York, NY',
#                                'name': 'Heather Hogan',
#                                'notifications': None,
#                                'profile_background_color': 'CCCCCC',
#                                'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/410754721/TwitterBackground.png',
#                                'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/410754721/TwitterBackground.png',
#                                'profile_background_tile': True,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21411216/1510536686',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/790575134478331904/6I2iC3E2_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/790575134478331904/6I2iC3E2_normal.jpg',
#                                'profile_link_color': 'ABB8C2',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': 'F5F5F5',
#                                'profile_text_color': '000000',
#                                'profile_use_background_image': False,
#                                'protected': False,
#                                'screen_name': 'theheatherhogan',
#                                'statuses_count': 40513,
#                                'time_zone': 'Eastern Time (US & Canada)',
#                                'translator_type': 'none',
#                                'url': 'https://t.co/kZv3R2lryS',
#                                'utc_offset': -14400,
#                                'verified': True}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @theheatherhogan: Guy to bartender: “I’m working with some '
#          'celebrities right now. People with three thousand followers will '
#          'come to your…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Mar 06 18:36:40 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'We learn to love not when we find the perfect '
#                          'person, but when we got to see so perfect an '
#                          'imperfect person. #Barça',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 1256,
#           'follow_request_sent': None,
#           'followers_count': 1133,
#           'following': None,
#           'friends_count': 195,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 261796131,
#           'id_str': '261796131',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'es',
#           'listed_count': 3,
#           'location': '',
#           'name': 'Ingnite',
#           'notifications': None,
#           'profile_background_color': 'BADFCD',
#           'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/443925305082642433/RG-JMirY.jpeg',
#           'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/443925305082642433/RG-JMirY.jpeg',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/261796131/1453896564',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/584905483208695808/7yhGbUIg_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/584905483208695808/7yhGbUIg_normal.jpg',
#           'profile_link_color': '00FF00',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': '95E8EC',
#           'profile_text_color': '09C0E0',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'Ingnite96',
#           'statuses_count': 9997,
#           'time_zone': 'Mexico City',
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': -18000,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:53 +0000 2018',
#  'entities': {'hashtags': [{'indices': [0, 5], 'text': '一番搾り'},
#                            {'indices': [6, 22], 'text': 'それはおいしいビールのつくり方'}],
#               'symbols': [],
#               'urls': [{'display_url': 'goo.gl/rfYFjc',
#                         'expanded_url': 'https://goo.gl/rfYFjc',
#                         'indices': [23, 46],
#                         'url': 'https://t.co/2opFSTqz6h'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954394924417024,
#  'id_str': '990954394924417024',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'und',
#  'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': '#一番搾り #それはおいしいビールのつくり方 https://t.co/2opFSTqz6h',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Oct 18 12:44:40 +0000 2015',
#           'default_profile': True,
#           'default_profile_image': True,
#           'description': '宮城県にすんでます。誰彼構わずフォローしますので、よろしくお願いします！',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 2728,
#           'follow_request_sent': None,
#           'followers_count': 362,
#           'following': None,
#           'friends_count': 1105,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 3936021319,
#           'id_str': '3936021319',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'ja',
#           'listed_count': 1,
#           'location': '究極の聖地',
#           'name': 'カニ',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#           'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'FclgqwQDO6ogJu1',
#           'statuses_count': 6094,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:53 +0000 2018',
#  'entities': {'hashtags': [{'indices': [66, 76], 'text': 'TheRapper'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 956030347610939392,
#                                  'id_str': '956030347610939392',
#                                  'indices': [3, 16],
#                                  'name': 'นุ้งอ้อน',
#                                  'screen_name': 'aonannjunrai'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954393162825728,
#  'id_str': '990954393162825728',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'th',
#  'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 6460,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Mon Apr 23 14:02:40 +0000 2018',
#                       'entities': {'hashtags': [{'indices': [48, 58],
#                                                  'text': 'TheRapper'}],
#                                    'symbols': [],
#                                    'urls': [],
#                                    'user_mentions': []},
#                       'favorite_count': 1190,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 988417877018472449,
#                       'id_str': '988417877018472449',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'th',
#                       'metadata': {'iso_language_code': 'th',
#                                    'result_type': 'recent'},
#                       'place': None,
#                       'retweet_count': 6460,
#                       'retweeted': False,
#                       'source': '<a href="http://twitter.com/download/android" '
#                                 'rel="nofollow">Twitter for Android</a>',
#                       'text': 'อายุ13ยังมา พี่กอล์ฟคะส่งชูใจมาแร็ปรถแดงเถอะค่ะ '
#                               '#TheRapper',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Wed Jan 24 05:06:11 +0000 2018',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'uueuoe ._.',
#                                'entities': {'description': {'urls': []}},
#                                'favourites_count': 13,
#                                'follow_request_sent': None,
#                                'followers_count': 21,
#                                'following': None,
#                                'friends_count': 131,
#                                'geo_enabled': True,
#                                'has_extended_profile': True,
#                                'id': 956030347610939392,
#                                'id_str': '956030347610939392',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'th',
#                                'listed_count': 0,
#                                'location': 'สุพรรณบุรี, ประเทศไทย',
#                                'name': 'นุ้งอ้อน',
#                                'notifications': None,
#                                'profile_background_color': '000000',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/956030347610939392/1519627491',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/990571889230663680/Vz-LDTV8_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/990571889230663680/Vz-LDTV8_normal.jpg',
#                                'profile_link_color': 'E81C4F',
#                                'profile_sidebar_border_color': '000000',
#                                'profile_sidebar_fill_color': '000000',
#                                'profile_text_color': '000000',
#                                'profile_use_background_image': False,
#                                'protected': False,
#                                'screen_name': 'aonannjunrai',
#                                'statuses_count': 776,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': None,
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @aonannjunrai: อายุ13ยังมา พี่กอล์ฟคะส่งชูใจมาแร็ปรถแดงเถอะค่ะ '
#          '#TheRapper',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Nov 18 08:02:56 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '#1997 #QingYu #WangQing #FengJainyu ♦️',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 1565,
#           'follow_request_sent': None,
#           'followers_count': 178,
#           'following': None,
#           'friends_count': 761,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 415381225,
#           'id_str': '415381225',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 4,
#           'location': 'Trang',
#           'name': 'beerforgot',
#           'notifications': None,
#           'profile_background_color': 'BADFCD',
#           'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/684980838807678976/uOBt37bK.jpg',
#           'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/684980838807678976/uOBt37bK.jpg',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/415381225/1460657463',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/820856428424359936/m3duM21r_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820856428424359936/m3duM21r_normal.jpg',
#           'profile_link_color': 'E81C4F',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': 'F5F0F5',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'Beer_Kanyarat',
#           'statuses_count': 56895,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:53 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'dogu-beer.blog.so-net.ne.jp/2018-04-30',
#                         'expanded_url': 'http://dogu-beer.blog.so-net.ne.jp/2018-04-30',
#                         'indices': [28, 51],
#                         'url': 'https://t.co/T4cuhVqhG1'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954393125044224,
#  'id_str': '990954393125044224',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'ja',
#  'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://blog.so-net.ne.jp" rel="nofollow">So-netブログ</a>',
#  'text': '『土偶の、呟き。 2018/04/30』居酒屋、土偶。｜https://t.co/T4cuhVqhG1',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat Jul 24 02:19:54 +0000 2010',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '丸烏賊ホールディングス株式会社 '
#                          '代表取締役社長。LGBTストレートアライ。立ち話もなんだからアタシの店に寄ってかない？  ぷしゅ♪',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'dogu-beer.blog.so-net.ne.jp',
#                                          'expanded_url': 'http://dogu-beer.blog.so-net.ne.jp/',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/5tqlmdLGW1'}]}},
#           'favourites_count': 580,
#           'follow_request_sent': None,
#           'followers_count': 269,
#           'following': None,
#           'friends_count': 274,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 170154604,
#           'id_str': '170154604',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'ja',
#           'listed_count': 14,
#           'location': '江戸朱引内',
#           'name': '土偶™',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/150931715/meireki.jpg',
#           'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/150931715/meireki.jpg',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170154604/1499203564',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/978995934817271809/VIDQfXNy_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978995934817271809/VIDQfXNy_normal.jpg',
#           'profile_link_color': '80460C',
#           'profile_sidebar_border_color': 'F2F593',
#           'profile_sidebar_fill_color': 'F5EDB8',
#           'profile_text_color': '4D2C05',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'dogu_beer',
#           'statuses_count': 24938,
#           'time_zone': 'Tokyo',
#           'translator_type': 'none',
#           'url': 'https://t.co/5tqlmdLGW1',
#           'utc_offset': 32400,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:52 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                         'expanded_url': 'https://twitter.com/i/web/status/990954391149711361',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/7Hth7yWIsK'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954391149711361,
#  'id_str': '990954391149711361',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://www.facebook.com/twitter" '
#            'rel="nofollow">Facebook</a>',
#  'text': 'Another one for the foodie in you! Enjoy gourmet food, fine wine, '
#          'beer, cocktails, local music, and a silent auctio… '
#          'https://t.co/7Hth7yWIsK',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Feb 11 14:24:07 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': "Welcome to Marietta's premier apartment community, "
#                          'Rockledge!',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'rockledgeatl.com',
#                                          'expanded_url': 'http://www.rockledgeatl.com',
#                                          'indices': [0, 22],
#                                          'url': 'http://t.co/n3KIM16oSp'}]}},
#           'favourites_count': 0,
#           'follow_request_sent': None,
#           'followers_count': 1557,
#           'following': None,
#           'friends_count': 396,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 20592672,
#           'id_str': '20592672',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': 'Marietta, GA',
#           'name': 'Rockledge Apartments',
#           'notifications': None,
#           'profile_background_color': '352726',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1664505500/Rockledge_LOGO_wht_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1664505500/Rockledge_LOGO_wht_normal.jpg',
#           'profile_link_color': 'D02B55',
#           'profile_sidebar_border_color': '829D5E',
#           'profile_sidebar_fill_color': '99CC33',
#           'profile_text_color': '3E4415',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'RockledgeApts',
#           'statuses_count': 846,
#           'time_zone': 'Eastern Time (US & Canada)',
#           'translator_type': 'none',
#           'url': 'http://t.co/n3KIM16oSp',
#           'utc_offset': -14400,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:51 +0000 2018',
#  'entities': {'hashtags': [],
#               'media': [{'display_url': 'pic.twitter.com/cJOmRjBjAs',
#                          'expanded_url': 'https://twitter.com/kangdanielpd101/status/990878428244119552/photo/1',
#                          'id': 990878422300798978,
#                          'id_str': '990878422300798978',
#                          'indices': [45, 68],
# ...
#           'profile_background_image_url': None,
#           'profile_background_image_url_https': None,
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4616661496/1525062117',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/988792473861402625/bI3ZGjJ4_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988792473861402625/bI3ZGjJ4_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'yairisfonsecaa',
#           'statuses_count': 44,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:46 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 559269669,
#                                  'id_str': '559269669',
#                                  'indices': [3, 15],
#                                  'name': 'thebeerists',
#                                  'screen_name': 'thebeerists'},
#                                 {'id': 1668443695,
#                                  'id_str': '1668443695',
#                                  'indices': [70, 81],
#                                  'name': 'LERVIG',
#                                  'screen_name': 'LervigBeer'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954367783178241,
#  'id_str': '990954367783178241',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 1,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Mon Apr 30 14:00:03 +0000 2018',
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                                              'expanded_url': 'https://twitter.com/i/web/status/990953931743391745',
#                                              'indices': [115, 138],
#                                              'url': 'https://t.co/ES434P43Oz'}],
#                                    'user_mentions': [{'id': 1668443695,
#                                                       'id_str': '1668443695',
#                                                       'indices': [53, 64],
#                                                       'name': 'LERVIG',
#                                                       'screen_name': 'LervigBeer'}]},
#                       'favorite_count': 1,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 990953931743391745,
#                       'id_str': '990953931743391745',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'metadata': {'iso_language_code': 'en',
#                                    'result_type': 'recent'},
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 1,
#                       'retweeted': False,
#                       'source': '<a '
#                                 'href="https://about.twitter.com/products/tweetdeck" '
#                                 'rel="nofollow">TweetDeck</a>',
#                       'text': 'The Beerists 324 - Beer From Norway!\n'
#                               '\n'
#                               'Beer reviewed:\n'
#                               '@LervigBeer Supersonic DIPA, Barley Wine '
#                               '(2017), and Lervig/… https://t.co/ES434P43Oz',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Sat Apr 21 04:16:14 +0000 2012',
#                                'default_profile': True,
#                                'default_profile_image': False,
#                                'description': 'The Beerists is a podcast about '
#                                               'craft beer. Like us on '
#                                               'http://t.co/KhohGpXy',
#                                'entities': {'description': {'urls': [{'display_url': 'facebook.com/thebeerists',
#                                                                       'expanded_url': 'http://www.facebook.com/thebeerists',
#                                                                       'indices': [55,
#                                                                                   75],
#                                                                       'url': 'http://t.co/KhohGpXy'}]},
#                                             'url': {'urls': [{'display_url': 'thebeerists.com',
#                                                               'expanded_url': 'http://www.thebeerists.com',
#                                                               'indices': [0,
#                                                                           22],
#                                                               'url': 'http://t.co/2XimB0Ex9I'}]}},
#                                'favourites_count': 1143,
#                                'follow_request_sent': None,
#                                'followers_count': 1852,
#                                'following': None,
#                                'friends_count': 680,
#                                'geo_enabled': False,
#                                'has_extended_profile': False,
#                                'id': 559269669,
#                                'id_str': '559269669',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 57,
#                                'location': 'Austin, TX',
#                                'name': 'thebeerists',
#                                'notifications': None,
#                                'profile_background_color': 'C0DEED',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/559269669/1467358249',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/872565715924013056/e7ND8h8e_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/872565715924013056/e7ND8h8e_normal.jpg',
#                                'profile_link_color': '1DA1F2',
#                                'profile_sidebar_border_color': 'C0DEED',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'thebeerists',
#                                'statuses_count': 1875,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'http://t.co/2XimB0Ex9I',
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': 'RT @thebeerists: The Beerists 324 - Beer From Norway!\n'
#          '\n'
#          'Beer reviewed:\n'
#          '@LervigBeer Supersonic DIPA, Barley Wine (2017), and Lervig/ '
#          '@EvilTwi…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Nov 25 15:48:40 +0000 2008',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '📺: https://t.co/LMpfK9YHcN 🍺: '
#                          'https://t.co/tdw88MOTtQ 🎮: https://t.co/0h2AEhCbKo '
#                          '🖖: https://t.co/kSBIAy9A7A 🎙: '
#                          'https://t.co/coKCGzZ03o',
#           'entities': {'description': {'urls': [{'display_url': 'thetvdudes.com',
#                                                  'expanded_url': 'http://thetvdudes.com',
#                                                  'indices': [3, 26],
#                                                  'url': 'https://t.co/LMpfK9YHcN'},
#                                                 {'display_url': 'thebeerists.com',
#                                                  'expanded_url': 'http://thebeerists.com',
#                                                  'indices': [30, 53],
#                                                  'url': 'https://t.co/tdw88MOTtQ'},
#                                                 {'display_url': 'rageselect.com',
#                                                  'expanded_url': 'http://rageselect.com',
#                                                  'indices': [57, 80],
#                                                  'url': 'https://t.co/0h2AEhCbKo'},
#                                                 {'display_url': 'startrekpod.com',
#                                                  'expanded_url': 'http://startrekpod.com',
#                                                  'indices': [84, 107],
#                                                  'url': 'https://t.co/kSBIAy9A7A'},
#                                                 {'display_url': 'permanentrcrd.com',
#                                                  'expanded_url': 'http://permanentrcrd.com',
#                                                  'indices': [111, 134],
#                                                  'url': 'https://t.co/coKCGzZ03o'}]},
#                        'url': {'urls': [{'display_url': 'thetvdudes.com',
#                                          'expanded_url': 'http://www.thetvdudes.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/ZytZreFC28'}]}},
#           'favourites_count': 5864,
#           'follow_request_sent': None,
#           'followers_count': 2386,
#           'following': None,
#           'friends_count': 355,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 17622141,
#           'id_str': '17622141',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 58,
#           'location': 'Austin, TX',
#           'name': 'Grant Davis',
#           'notifications': None,
#           'profile_background_color': 'C6E2EE',
#           'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/852487176/a2d7d9401e24ca1f4a3c1f7c2d520651.png',
#           'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/852487176/a2d7d9401e24ca1f4a3c1f7c2d520651.png',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17622141/1505934925',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/881885338729418752/t4FybT72_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/881885338729418752/t4FybT72_normal.jpg',
#           'profile_link_color': '1B95E0',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'DAECF4',
#           'profile_text_color': '1F98C7',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'BaronVonGrant',
#           'statuses_count': 11845,
#           'time_zone': 'Central Time (US & Canada)',
#           'translator_type': 'none',
#           'url': 'https://t.co/ZytZreFC28',
#           'utc_offset': -18000,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 30 14:01:46 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 447510448,
#                                  'id_str': '447510448',
#                                  'indices': [0, 15],
#                                  'name': 'Reise Durrant',
#                                  'screen_name': 'ReiseDurrant16'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 990954363739750408,
#  'id_str': '990954363739750408',
#  'in_reply_to_screen_name': 'ReiseDurrant16',
#  'in_reply_to_status_id': 990795194864885760,
#  'in_reply_to_status_id_str': '990795194864885760',
#  'in_reply_to_user_id': 447510448,
#  'in_reply_to_user_id_str': '447510448',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': '@ReiseDurrant16 I dunno why I was so angry, someone get me a beer 😏',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Nov 21 20:25:11 +0000 2013',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 2350,
#           'follow_request_sent': None,
#           'followers_count': 98,
#           'following': None,
#           'friends_count': 199,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 2207776428,
#           'id_str': '2207776428',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 2,
#           'location': 'Planet Earth',
#           'name': 'Ty',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2207776428/1469559612',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/871591024480497664/x4lvCKDE_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/871591024480497664/x4lvCKDE_normal.jpg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'hudec29',
#           'statuses_count': 635,
#           'time_zone': 'Mountain Time (US & Canada)',
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': -21600,
#           'verified': False}}
